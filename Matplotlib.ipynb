# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
area = ['marketing', 'hr','dev', 'hosing']
budget = [123,342,123,243]
plt.pie(budget,labels = area)
plt.show()

# %%
budget = [123,342,123,243, 234, 52, 45, 334, 323, 5,324 ,34,45 ,34,45 ,34, 324,34 ,34,34 ,4,5 ,45, 3, 1]
to =[43, 234, 52, 45, 334, 323, 5,324 ,34,45 ,34,45 ,34, 324,34 ,34,34 ,4,5 ,45, 3, 1, 234, 234, 34]
plt.scatter(budget, to)

# %%
id = [1,2,3,4,5,6]
price1 = [12,23,12,34,5,65]
price2 = [34,23,12,34,23,45]
plt.plot(id, price1)
plt.plot(id, price2, color = 'red')
