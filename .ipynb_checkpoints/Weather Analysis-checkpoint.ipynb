# %%
import numpy as np
# %matplotlib inline
from copy import deepcopy
import pandas as pd
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (16,9)
plt.style.use('ggplot')

# %%
data = pd.read_csv('C:/Users/Nirbhay Kumar/DataScience/weather.csv')
print(data.shape)
data.head()
# Out:
# (366, 22)
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df = pd.DataFrame(data)
newdf = df[['Temp9am', 'Temp3pm', 'Pressure3pm', 'Pressure9am']]
newdf.head()
# Out:
#    Temp9am  Temp3pm  Pressure3pm  Pressure9am
# 0     14.4     23.6       1015.0       1019.7
# 1     17.5     25.7       1008.4       1012.4
# 2     15.4     20.2       1007.2       1009.5
# 3     13.5     14.1       1007.0       1005.5
# 4     11.1     15.4       1018.5       1018.3

# %%
## newdf['TempDiff'] = newdf['Temp9am'] - newdf['Temp3pm'] 

df1 = pd.DataFrame(data, columns = ['Temp9am', 'Temp3pm', 'Pressure3pm', 'Pressure9am'])
df1
# Out:
#     Temp9am  Temp3pm  Pressure3pm  Pressure9am
# 0       NaN      NaN          NaN          NaN
# 1       NaN      NaN          NaN          NaN
# 2       NaN      NaN          NaN          NaN
# 3       NaN      NaN          NaN          NaN
# 4       NaN      NaN          NaN          NaN
# 5       NaN      NaN          NaN          NaN
# 6       NaN      NaN          NaN          NaN
# 7       NaN      NaN          NaN          NaN
# 8       NaN      NaN          NaN          NaN
# 9       NaN      NaN          NaN          NaN
# 10      NaN      NaN          NaN          NaN
# 11      NaN      NaN          NaN          NaN
# 12      NaN      NaN          NaN          NaN
# 13      NaN      NaN          NaN          NaN
# 14      NaN      NaN          NaN          NaN
# 15      NaN      NaN          NaN          NaN
# 16      NaN      NaN          NaN          NaN
# 17      NaN      NaN          NaN          NaN
# 18      NaN      NaN          NaN          NaN
# ...

# %%
df1['TempDiff', 'PressureDiff'] = df1['Temp9am'] - df1['Temp3pm'], df1['Pressure3pm'] - df1['Pressure9am']
df1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-c49428a9c7e2> in <module>
# ----> 1 df1['TempDiff', 'PressureDiff'] = df1['Temp9am'] - df1['Temp3pm'], df1['Pressure3pm'] - df1['Pressure9am']
#       2 df1
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#    3002
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3634
# ...

# %%
df1
# Out:
#     Temp9am  Temp3pm  Pressure3pm  Pressure9am
# 0       NaN      NaN          NaN          NaN
# 1       NaN      NaN          NaN          NaN
# 2       NaN      NaN          NaN          NaN
# 3       NaN      NaN          NaN          NaN
# 4       NaN      NaN          NaN          NaN
# 5       NaN      NaN          NaN          NaN
# 6       NaN      NaN          NaN          NaN
# 7       NaN      NaN          NaN          NaN
# 8       NaN      NaN          NaN          NaN
# 9       NaN      NaN          NaN          NaN
# 10      NaN      NaN          NaN          NaN
# 11      NaN      NaN          NaN          NaN
# 12      NaN      NaN          NaN          NaN
# 13      NaN      NaN          NaN          NaN
# 14      NaN      NaN          NaN          NaN
# 15      NaN      NaN          NaN          NaN
# 16      NaN      NaN          NaN          NaN
# 17      NaN      NaN          NaN          NaN
# 18      NaN      NaN          NaN          NaN
# ...

# %%
df1[ 'PressureDiff'] = df1['Pressure3pm'] - df1['Pressure9am']
df1
# Out:
#      Temp9am  Temp3pm  Pressure3pm  Pressure9am  TempDiff  PressureDiff
# 0       14.4     23.6       1015.0       1019.7      -9.2          -4.7
# 1       17.5     25.7       1008.4       1012.4      -8.2          -4.0
# 2       15.4     20.2       1007.2       1009.5      -4.8          -2.3
# 3       13.5     14.1       1007.0       1005.5      -0.6           1.5
# 4       11.1     15.4       1018.5       1018.3      -4.3           0.2
# ..       ...      ...          ...          ...       ...           ...
# 361     20.4     30.0       1010.8       1016.1      -9.6          -5.3
# 362     17.2     28.2       1016.9       1020.0     -11.0          -3.1
# 363     14.5     18.3       1022.8       1024.0      -3.8          -1.2
# 364     15.8     25.9       1016.2       1021.0     -10.1          -4.8
# 365     23.8     28.6       1009.2       1009.6      -4.8          -0.4
#
# [366 rows x 6 columns]

# %%
print("j")
# Out:
# j

# %%
newdf = pd.DataFrame(df1, columns = ['TempDiff', 'PressureDiff'])

# %%
df1
# Out:
#      Temp9am  Temp3pm  Pressure3pm  Pressure9am  TempDiff  PressureDiff
# 0       14.4     23.6       1015.0       1019.7      -9.2          -4.7
# 1       17.5     25.7       1008.4       1012.4      -8.2          -4.0
# 2       15.4     20.2       1007.2       1009.5      -4.8          -2.3
# 3       13.5     14.1       1007.0       1005.5      -0.6           1.5
# 4       11.1     15.4       1018.5       1018.3      -4.3           0.2
# ..       ...      ...          ...          ...       ...           ...
# 361     20.4     30.0       1010.8       1016.1      -9.6          -5.3
# 362     17.2     28.2       1016.9       1020.0     -11.0          -3.1
# 363     14.5     18.3       1022.8       1024.0      -3.8          -1.2
# 364     15.8     25.9       1016.2       1021.0     -10.1          -4.8
# 365     23.8     28.6       1009.2       1009.6      -4.8          -0.4
#
# [366 rows x 6 columns]

# %%
newdf
# Out:
#      TempDiff  PressureDiff
# 0        -9.2          -4.7
# 1        -8.2          -4.0
# 2        -4.8          -2.3
# 3        -0.6           1.5
# 4        -4.3           0.2
# ..        ...           ...
# 361      -9.6          -5.3
# 362     -11.0          -3.1
# 363      -3.8          -1.2
# 364     -10.1          -4.8
# 365      -4.8          -0.4
#
# [366 rows x 2 columns]

# %%
finaldf
# Out:
#     TempDiff  PressureDiff
# 0        9.2           4.7
# 1        8.2           4.0
# 2        4.8           2.3
# 3        0.6          -1.5
# 4        4.3          -0.2
# 5        3.9           2.1
# 6        4.9           2.4
# 7        3.4           2.0
# 8        4.8           3.4
# 9        8.4           3.4
# 10       9.4           3.3
# 11       9.2           3.9
# 12      10.1           4.9
# 13      11.0           4.2
# 14      11.7           4.5
# 15      11.6           5.1
# 16       9.6           4.6
# 17       8.5           3.4
# 18      11.0           3.8
# 19       9.2           4.8

# %%
finaldf = finaldf*-1
finaldf
# Out:
#     TempDiff  PressureDiff
# 0       -9.2          -4.7
# 1       -8.2          -4.0
# 2       -4.8          -2.3
# 3       -0.6           1.5
# 4       -4.3           0.2
# 5       -3.9          -2.1
# 6       -4.9          -2.4
# 7       -3.4          -2.0
# 8       -4.8          -3.4
# 9       -8.4          -3.4
# 10      -9.4          -3.3
# 11      -9.2          -3.9
# 12     -10.1          -4.9
# 13     -11.0          -4.2
# 14     -11.7          -4.5
# 15     -11.6          -5.1
# 16      -9.6          -4.6
# 17      -8.5          -3.4
# 18     -11.0          -3.8
# 19      -9.2          -4.8

# %%
data = finaldf
data
# Out:
#     TempDiff  PressureDiff
# 0        9.2           4.7
# 1        8.2           4.0
# 2        4.8           2.3
# 3        0.6          -1.5
# 4        4.3          -0.2
# 5        3.9           2.1
# 6        4.9           2.4
# 7        3.4           2.0
# 8        4.8           3.4
# 9        8.4           3.4
# 10       9.4           3.3
# 11       9.2           3.9
# 12      10.1           4.9
# 13      11.0           4.2
# 14      11.7           4.5
# 15      11.6           5.1
# 16       9.6           4.6
# 17       8.5           3.4
# 18      11.0           3.8
# 19       9.2           4.8

# %%
f1 = data['TempDiff'].values
f2 = data['PressureDiff'].values
X  = np.array(list(zip(f1,f2)))
plt.scatter(f1,f2, s = 20)

# %%
newdf
# Out:
#      TempDiff  PressureDiff
# 0        -9.2          -4.7
# 1        -8.2          -4.0
# 2        -4.8          -2.3
# 3        -0.6           1.5
# 4        -4.3           0.2
# ..        ...           ...
# 361      -9.6          -5.3
# 362     -11.0          -3.1
# 363      -3.8          -1.2
# 364     -10.1          -4.8
# 365      -4.8          -0.4
#
# [366 rows x 2 columns]

# %%
finaldf = newdf*-1

# %%
finaldf
# Out:
#      TempDiff  PressureDiff
# 0         9.2           4.7
# 1         8.2           4.0
# 2         4.8           2.3
# 3         0.6          -1.5
# 4         4.3          -0.2
# ..        ...           ...
# 361       9.6           5.3
# 362      11.0           3.1
# 363       3.8           1.2
# 364      10.1           4.8
# 365       4.8           0.4
#
# [366 rows x 2 columns]

# %%
f1 = finaldf['TempDiff'].values
f2 = finaldf['PressureDiff'].values
X  = np.array(list(zip(f1,f2)))
plt.scatter(f1,f2, s = 20)

# %%
#euclidian distane calculator
def dist(a,b, ax =1):
    return np.linalg.norm(a - b, axis = ax)
#no of clusters
k  = 3

#x coordinate of random centroid
c_x = np.random.randint(0, np.max(X) - 20, size = k)

#x coordinate of random centroid
c_y = np.random.randint(0, np.max(X) - 20, size = k)

c  = np.array(list(zip(c_x, c_y)), dtype = np.float32)
print(c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-d53231ed367a> in <module>
#       6
#       7 #x coordinate of random centroid
# ----> 8 c_x = np.random.randint(0, np.max(X) - 20, size = k)
#       9
#      10 #x coordinate of random centroid
#
# mtrand.pyx in numpy.random.mtrand.RandomState.randint()
#
# _bounded_integers.pyx in numpy.random._bounded_integers._rand_int32()
#
# ValueError: low >= high

# %%
X
# Out:
# array([[ 9.2,  4.7],
#        [ 8.2,  4. ],
#        [ 4.8,  2.3],
#        [ 0.6, -1.5],
#        [ 4.3, -0.2],
#        [ 3.9,  2.1],
#        [ 4.9,  2.4],
#        [ 3.4,  2. ],
#        [ 4.8,  3.4],
#        [ 8.4,  3.4],
#        [ 9.4,  3.3],
#        [ 9.2,  3.9],
#        [10.1,  4.9],
#        [11. ,  4.2],
#        [11.7,  4.5],
#        [11.6,  5.1],
#        [ 9.6,  4.6],
#        [ 8.5,  3.4],
#        [11. ,  3.8],
#        [ 9.2,  4.8],
#        [10.6,  5.9],
#        [ 1.8,  1.8],
#        [ 2.8, -0.9],
#        [ 5. ,  1.5],
#        [10.5,  3.8],
#        [ 5.3,  3.2],
#        [ 4.7,  2.4],
#        [ 7.9,  4.4],
#        [ 0.8,  1.9],
#        [ 5.9,  3.9],
#        [-0.7,  0.9],
#        [ 8.5,  4.4],
#        [-0.6,  3.3],
#        [ 6.3,  1. ],
#        [ 1.9, -0.3],
#        [ 5.9,  2.7],
#        [ 1.1,  3. ],
#        [ 8.3,  3.4],
#        [ 8. ,  2.3],
#        [ 3.6,  1.3],
#        [ 2.6,  0.6],
#        [ 3.7,  1.5],
#        [ 3.4,  2.6],
# ...
