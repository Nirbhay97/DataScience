# %%
import numpy as np
import pandas as pd

# %%
company = pd.read_csv('C:/Users/Nirbhay Kumar/Downloads/Fortune 500 Companies US.csv', encoding='ISO-8859-1')
company
# Out:
#      Rank        Company Name Number of Employees  Previous Rank   Revenues  \
# 0       1             Walmart           23,00,000            1.0  $4,85,873
# 1       2  Berkshire Hathaway            3,67,700            4.0  $2,23,604
# 2       3               Apple            1,16,000            3.0  $2,15,639
# 3       4         Exxon Mobil              72,700            2.0  $2,05,004
# 4       5            McKesson              68,000            5.0  $1,92,487
# ..    ...                 ...                 ...            ...        ...
# 495   496       Michaels Cos.              31,000          517.0     $5,197
# 496   497       Toll Brothers               4,200          576.0     $5,170
# 497   498               Yahoo               8,500          513.0     $5,169
# 498   499       Vistra Energy               4,431            NaN     $5,164
# 499   500      ABM Industries            1,10,000          485.0     $5,145
#
# ...

# %%
com = company.groupby('Profits')

# %%
com

# %%
len(com)
# Out:
# 495

# %%
len(company)
# Out:
# 500

# %%
com.size().sort_values(ascending= False)
# Out:
# Profits
# $396.0      2
# $1,768.0    2
# $324.0      2
# $734.0      2
# $382.1      2
#            ..
# $610.9      1
# $611.0      1
# $612.6      1
# $614.0      1
# $1,006.0    1
# Length: 495, dtype: int64

# %%
com.first()
# Out:
#           Rank                    Company Name Number of Employees  \
# Profits
# $1,006.0    75  Liberty Mutual Insurance Group              50,000
# $1,027.0   341                    Weyerhaeuser              10,400
# $1,031.0   120                     Progressive              31,721
# $1,037.7   323             OÕReilly Automotive              58,397
# $1,045.0   451        Citizens Financial Group              17,600
# ...        ...                             ...                 ...
# -$7.8      441                AK Steel Holding               8,500
# -$774.0    229                      NRG Energy               8,763
# -$849.0     55                             AIG              56,400
# -$941.0    228                           Alcoa              41,500
# -$97.0     337          Navistar International              11,300
#
#           Previous Rank Revenues Revenue Change Profit Change     Assets  \
# Profits
# ...

# %%
com.groups
# Out:
# {'$1,006.0': Int64Index([74], dtype='int64'),
#  '$1,027.0': Int64Index([340], dtype='int64'),
#  '$1,031.0': Int64Index([119], dtype='int64'),
#  '$1,037.7': Int64Index([322], dtype='int64'),
#  '$1,045.0': Int64Index([450], dtype='int64'),
#  '$1,054.9': Int64Index([407], dtype='int64'),
#  '$1,067.0': Int64Index([285], dtype='int64'),
#  '$1,074.1': Int64Index([229], dtype='int64'),
#  '$1,088.1': Int64Index([64], dtype='int64'),
#  '$1,101.4': Int64Index([296], dtype='int64'),
#  '$1,114.6': Int64Index([252], dtype='int64'),
#  '$1,117.7': Int64Index([218], dtype='int64'),
#  '$1,123.4': Int64Index([255], dtype='int64'),
#  '$1,132.7': Int64Index([235], dtype='int64'),
#  '$1,134.0': Int64Index([88], dtype='int64'),
#  '$1,148.6': Int64Index([178], dtype='int64'),
#  '$1,158.1': Int64Index([219], dtype='int64'),
#  '$1,163.0': Int64Index([435], dtype='int64'),
#  '$1,168.8': Int64Index([442], dtype='int64'),
#  '$1,174.0': Int64Index([50], dtype='int64'),
# ...

# %%
company['']
